# %%
from quantum_sensing.optimizer import run_trial

hamiltonian_parameters = {
    "rabi_frequency": (50 * (10 ** 3)),
    "omega_m": (2.75 * (10 ** 6)),
    "mu": (14 * (10 ** 3)),
    "hamiltonian_type": "zig_zag",
}
circuit_hyperparameters = {
    "num_qubits": 5,
    "num_blocks": 4,
}

run_trial(circuit_hyperparameters, hamiltonian_parameters)
# Out:
# 2025/12/29 16:57:05 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/29 16:57:05 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/29 16:57:05 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 16:57:05 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/29 16:57:05 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 16:57:05 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# /Users/tarun/Study/duke/quantum-sensing/quantum_sensing/optimizer.py:112: RuntimeWarning: Maximum number of iterations has been exceeded.
#   optimized_result = minimize(cost_history_logger, initial_guess, method='Nelder-Mead', options=options)
