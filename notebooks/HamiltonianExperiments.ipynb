# %%
from quantum_sensing import run_trial

hamiltonian_parameters = {
    "rabi_frequency": (50 * (10 ** 3)),
    "omega_m": (2.75 * (10 ** 6)),
    "mu": (14 * (10 ** 3)),
    "hamiltonian_type": "zig_zag",
}
circuit_hyperparameters = {
    "num_qubits": 5,
    "num_blocks": 4,
    "backend": 'pennylane'
}

run_trial(circuit_hyperparameters, hamiltonian_parameters)
# Out:
# 2025/12/29 21:15:04 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/29 21:15:04 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/29 21:15:04 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 21:15:04 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/29 21:15:04 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 21:15:04 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# /Users/tarun/Study/duke/quantum-sensing/quantum_sensing/optimization/optimizer.py:49: RuntimeWarning: Maximum number of iterations has been exceeded.
#   result = minimize(
