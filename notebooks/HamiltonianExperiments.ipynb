# %%
import sys
import os

# This is done to include the quantum-sensing module
sys.path.append(os.path.abspath('..'))

from quantum_sensing import run_trial

# %%
hamiltonian_parameters = {
    "rabi_frequency": (50 * (10 ** 3)),
    "omega_m": (2.75 * (10 ** 6)),
    "mu": (14 * (10 ** 3)),
    "hamiltonian_type": "com",
} 

circuit_hyperparameters = {
    "num_qubits": 5,
    "num_encoder_blocks": 0,
    "num_decoder_blocks": 2,
}

phi_signal_delta = 0.79

training_hyperparameters = {
"num_steps" : 20,
}

run_trial(circuit_hyperparameters, hamiltonian_parameters, phi_signal_delta, training_hyperparameters)
# Out:
# 2026/01/06 20:47:18 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/01/06 20:47:18 INFO mlflow.store.db.utils: Updating database tables
# 2026/01/06 20:47:18 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/06 20:47:18 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/06 20:47:18 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/01/06 20:47:18 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026/01/06 20:47:18 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2026/01/06 20:47:18 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# ld: warning: object file (/private/var/folders/m8/ss4zlk6s50n051yw97x7xm900000gn/T/qjit_compute_cost_gradw9_ihkh6/qjit_compute_cost_grad.o) was built for newer 'macOS' version (15.0) than being linked (14.2)
# ...
